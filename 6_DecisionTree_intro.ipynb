# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier

import matplotlib.pyplot as plt

# %%
data = {
    'Liver': [1, 1, 0, 0, 1, 1, 0],
    'Lung':  [1, 0, 1, 1, 1, 0, 0],
    'Age': [7, 12, 18, 35, 38, 50, 83]
}

target = [0, 0, 1, 1, 1, 0, 0]

# %%
df = pd.DataFrame(data)
df['Disease'] = target
df
# Out:
#    Liver  Lung  Age  Disease
# 0      1     1    7        0
# 1      1     0   12        0
# 2      0     1   18        1
# 3      0     1   35        1
# 4      1     1   38        1
# 5      1     0   50        0
# 6      0     0   83        0

# %%
tree = DecisionTreeClassifier()
tree.fit(df.drop(['Disease'], axis=1), target)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

fig, ax = plt.subplots(figsize=(10, 7))
plot_tree(tree, ax=ax)
plt.show()
